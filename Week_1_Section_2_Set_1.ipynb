# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie", "David"],
"Age": [25, 30, 35, 40],
"City": ["NYC", "LA", "Chicago", "Miami"],
"Email": ["a@example.com", "b@example.com", "c@example.com", "d@example.com"],
}

df = pd.DataFrame(data)

# %% [markdown]
# Excercise 1 - Drop the Email coumn and store the result in a new variable.

# %%
df_no_email = df.drop(columns=['Email'])

# %% [markdown]
# Excersise 2 - Drop the row with index 2 in place

# %%
df.drop(2, axis=0, inplace=True)
print(df)

# %% [markdown]
# Excercise 3 - Drop the City and Email columns, and assign the result back to df.

# %%
df = df.drop(['City', 'Email'], axis=1)
print(df)

# %% [markdown]
# Excersise 4 - Drop the first and last row, and store the result in `df_trimmed`

# %%
df_trimmed = df.drop([0, 3], axis=0)
print(df_trimmed)
# Out:
#       Name  Age     City          Email
# 1      Bob   30       LA  b@example.com
# 2  Charlie   35  Chicago  c@example.com
