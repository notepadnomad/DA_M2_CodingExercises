# %%
import pandas as pd

data = {
"Name": ["Alice", "Bob", "Charlie"],
"Dept": ["HR", "Finance", "IT"],
"Sal": [60000, 70000, 80000],
}

df = pd.DataFrame(data)

# %% [markdown]
# Exercise 1 - Rename Dept to Department and Sal to Salary

# %%
df.rename(columns={
    'Dept': 'Department',
    'Sal': 'Salary'
}, inplace=True)
df
# Out:
#       Name Department  Salary
# 0    Alice         HR   60000
# 1      Bob    Finance   70000
# 2  Charlie         IT   80000

# %% [markdown]
# Exercise 2 - Reorder columns so Salary appears first, followed by Name and Department.

# %%
df_reordered = df[['Salary', 'Name', 'Department']]

# %% [markdown]
# Excersise 3 - Show expected output for Reordering Columns.

# %%
df_reordered
# Out:
#    Salary     Name Department
# 0   60000    Alice         HR
# 1   70000      Bob    Finance
# 2   80000  Charlie         IT
